# %%
import numpy as np
import scipy
from scipy import stats
import qnm
from kuibit import simdir as sd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.colors import LogNorm
import pickle
from adjustText import adjust_text
import corner

plt.rcParams["xtick.labelsize"] = 25
plt.rcParams["ytick.labelsize"] = 25
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["xtick.major.size"] = 8
plt.rcParams["ytick.major.size"] = 8
plt.rcParams["xtick.minor.size"] = 4
plt.rcParams["ytick.minor.size"] = 4
plt.rcParams["xtick.top"] = True
plt.rcParams["ytick.right"] = True
plt.rcParams["axes.labelpad"] = 8
plt.rcParams["figure.constrained_layout.h_pad"] = 0
plt.rcParams["text.usetex"] = True
plt.rcParams["font.sans-serif"] = ["Times New Roman"]
plt.rcParams["mathtext.fontset"] = "stix"
plt.tick_params(axis="both", which="minor", labelsize=18)
# Out:
# /home/yuntian/anaconda3/envs/linux_QNM_env/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data=np.genfromtxt("try_gw150914_KN3_quick_example_0_ET_t10/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

fig=plt.figure(figsize=(8,8))
figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="red")



data=np.genfromtxt("try_gw150914_KN3_quick_example_10_ET_t10/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="blue")


data=np.genfromtxt("try_gw150914_KN3_quick_example_20_ET_t10/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="orange")

data=np.genfromtxt("try_gw150914_KN3_quick_example_30_ET_t10/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="purple")

# %%
data=np.genfromtxt("try_gw150914_KN_quick_example_0_ET/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

fig=plt.figure(figsize=(8,8))
figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="blue")

# %%
data=np.genfromtxt("try_gw150914_KN_quick_example_0/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

fig=plt.figure(figsize=(8,8))
figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="red")



data=np.genfromtxt("try_gw150914_KN_quick_example_o10/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="blue")


data=np.genfromtxt("try_gw150914_KN_quick_example_o20/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="orange")

data=np.genfromtxt("try_gw150914_KN_quick_example_o30/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="purple")

# %%
data=np.genfromtxt("try_gw150914_KN_quick_example_0/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

fig=plt.figure(figsize=(8,8))
figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="red")



data=np.genfromtxt("try_gw150914_KN_quick_example_10/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="blue")


data=np.genfromtxt("try_gw150914_KN_quick_example_20/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="orange")

data=np.genfromtxt("try_gw150914_KN_quick_example_30/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="purple")

# %%
data=np.genfromtxt("try_gw150914_KN_quick_example_0_ET_t10/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

fig=plt.figure(figsize=(8,8))
figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="red")



data=np.genfromtxt("try_gw150914_KN_quick_example_10_ET_t10/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="blue")


data=np.genfromtxt("try_gw150914_KN_quick_example_20_ET_t10/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="orange")

data=np.genfromtxt("try_gw150914_KN_quick_example_30_ET_t10/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="purple")

# %%
# 那么我们必须加入330模看看效果，不行的话提高信噪比再看看效果。。。。

# %%
data=np.genfromtxt("try_gw150914_KN_quick_example_10_ET/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af
fig=plt.figure(figsize=(8,8))
figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,color="blue")
# Out:
# WARNING:root:Too few points to create valid contours

# %%
data=np.genfromtxt("try_gw150914_KN_quick_example_0_t15/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

fig=plt.figure(figsize=(8,8))
figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="red")



data=np.genfromtxt("try_gw150914_KN_quick_example_10_t15/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="blue")


data=np.genfromtxt("try_gw150914_KN_quick_example_20_t15/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="orange")

data=np.genfromtxt("try_gw150914_KN_quick_example_30_t15/Nested_sampler/posterior.dat")
Q=data[:,4]
af=data[:,2]

corner_data=np.zeros([len(Q),2])
corner_data[:,0]=Q
corner_data[:,1]=af

figure=corner.corner(corner_data,labels=[r"$Q$",r"$a_f$"],label_kwargs={"fontsize":20},\
                     range=[(0,1),(0,1)],fig=fig,plot_contours=True,levels=[0.9],color="purple")

# %%
plt.figure(figsize=(12,8))

data=np.genfromtxt("NR_data_0/H-H1_GWOSC_4KHZ_R1-1126259447-32.txt")
plt.plot(np.abs(data))
data=np.genfromtxt("NR_data_o10/H-H1_GWOSC_4KHZ_R1-1126259447-32.txt")
plt.plot(np.abs(data))
data=np.genfromtxt("NR_data_o20/H-H1_GWOSC_4KHZ_R1-1126259447-32.txt")
plt.plot(np.abs(data))
data=np.genfromtxt("NR_data_o30/H-H1_GWOSC_4KHZ_R1-1126259447-32.txt")
plt.plot(np.abs(data))

plt.yscale("log")
plt.legend(["0","o10","o20","o30"])

plt.xlim([63150,63300])
# Out:
# (63150.0, 63300.0)

# %%
plt.figure(figsize=(12,8))

data=np.genfromtxt("NR_data_0/H-H1_GWOSC_4KHZ_R1-1126259447-32.txt")
plt.plot(np.abs(data))
data=np.genfromtxt("NR_data_10/H-H1_GWOSC_4KHZ_R1-1126259447-32.txt")
plt.plot(np.abs(data))
data=np.genfromtxt("NR_data_20/H-H1_GWOSC_4KHZ_R1-1126259447-32.txt")
plt.plot(np.abs(data))
data=np.genfromtxt("NR_data_30/H-H1_GWOSC_4KHZ_R1-1126259447-32.txt")
plt.plot(np.abs(data))

plt.yscale("log")
plt.legend(["0","10","20","30"])

plt.xlim([63150,63300])
# Out:
# (63150.0, 63300.0)

# %% [markdown]
# 如果从10M之后开始估计的话感觉可能就没有影响了？
# 我们就用15M吧

# %%
from kuibit import simdir as sd

plt.figure(figsize=(12,8))

name="0"
with sd.SimDir("/home/yuntian/vscode_codes/QNM_compare/Kerr_Newman/"+name,pickle_file="/home/yuntian/vscode_codes/QNM_compare/Kerr_Newman/"+name+".pickle") as sim:
    # print(sim)
    pass
psi4=sim.multipoles["psi4"][110.69]
psi4_22=psi4[2,2]
plt.plot(psi4_22.t-psi4_22.t[np.argmax(np.abs(psi4_22.values))],psi4_22.values.real)

name="o10"
with sd.SimDir("/home/yuntian/vscode_codes/QNM_compare/Kerr_Newman/"+name,pickle_file="/home/yuntian/vscode_codes/QNM_compare/Kerr_Newman/"+name+".pickle") as sim:
    # print(sim)
    pass
psi4=sim.multipoles["psi4"][110.69]
psi4_22=psi4[2,2]
plt.plot(psi4_22.t-psi4_22.t[np.argmax(np.abs(psi4_22.values))],psi4_22.values.real)

name="o20"
with sd.SimDir("/home/yuntian/vscode_codes/QNM_compare/Kerr_Newman/"+name,pickle_file="/home/yuntian/vscode_codes/QNM_compare/Kerr_Newman/"+name+".pickle") as sim:
    # print(sim)
    pass
psi4=sim.multipoles["psi4"][110.69]
psi4_22=psi4[2,2]
plt.plot(psi4_22.t-psi4_22.t[np.argmax(np.abs(psi4_22.values))],psi4_22.values.real)

name="o30"
with sd.SimDir("/home/yuntian/vscode_codes/QNM_compare/Kerr_Newman/"+name,pickle_file="/home/yuntian/vscode_codes/QNM_compare/Kerr_Newman/"+name+".pickle") as sim:
    # print(sim)
    pass
psi4=sim.multipoles["psi4"][110.69]
psi4_22=psi4[2,2]
plt.plot(psi4_22.t-psi4_22.t[np.argmax(np.abs(psi4_22.values))],psi4_22.values.real)

plt.legend(["0","o10","o20","o30"])

plt.xlim([-20,120])
# Out:
# (-20.0, 120.0)

# %%
plt.figure(figsize=(12,8))
data=np.genfromtxt("NR_data_0/Weyl4_mode_0_22.dat")
t=data[:,0]
psi4_r=data[:,1]
psi4_i=data[:,2]
# plt.plot(t-t[np.argmax(np.abs(psi4_r**2+psi4_i**2))],psi4_r)
plt.plot(t,psi4_r)

data=np.genfromtxt("NR_data_10/Weyl4_mode_0_22.dat")
t=data[:,0]
psi4_r=data[:,1]
psi4_i=data[:,2]
# plt.plot(t-t[np.argmax(np.abs(psi4_r**2+psi4_i**2))],psi4_r)
plt.plot(t,psi4_r)

data=np.genfromtxt("NR_data_20/Weyl4_mode_0_22.dat")
t=data[:,0]
psi4_r=data[:,1]
psi4_i=data[:,2]
# plt.plot(t-t[np.argmax(np.abs(psi4_r**2+psi4_i**2))],psi4_r)
plt.plot(t,psi4_r)

data=np.genfromtxt("NR_data_30/Weyl4_mode_0_22.dat")
t=data[:,0]
psi4_r=data[:,1]
psi4_i=data[:,2]
# plt.plot(t-t[np.argmax(np.abs(psi4_r**2+psi4_i**2))],psi4_r)
plt.plot(t,psi4_r)

plt.legend(["0","10","20","30"])
# plt.xlim([-220,120])
plt.ylim([-0.00002,0.00002])
# Out:
# (-2e-05, 2e-05)

# %%
data=np.genfromtxt("NR_data_0/strain_0_22_cutoff_low_0.005.dat")
t=data[:,0]
psi4_r=data[:,1]
psi4_i=data[:,2]
plt.plot(t-t[np.argmax(np.abs(psi4_r**2+psi4_i**2))],psi4_r)

data=np.genfromtxt("NR_data_o10/strain_0_22_cutoff_low_0.005.dat")
t=data[:,0]
psi4_r=data[:,1]
psi4_i=data[:,2]
plt.plot(t-t[np.argmax(np.abs(psi4_r**2+psi4_i**2))],psi4_r)

data=np.genfromtxt("NR_data_o20/strain_0_22_cutoff_low_0.005.dat")
t=data[:,0]
psi4_r=data[:,1]
psi4_i=data[:,2]
plt.plot(t-t[np.argmax(np.abs(psi4_r**2+psi4_i**2))],psi4_r)

data=np.genfromtxt("NR_data_o30/strain_0_22_cutoff_low_0.005.dat")
t=data[:,0]
psi4_r=data[:,1]
psi4_i=data[:,2]
plt.plot(t-t[np.argmax(np.abs(psi4_r**2+psi4_i**2))],psi4_r)

plt.legend(["0","o10","o20","o30"])
plt.xlim([-20,120])
# Out:
# (-20.0, 120.0)

# %%
plt.figure(figsize=(12,8))
data=np.genfromtxt("NR_data_0/strain_0_22_cutoff_low_0.005.dat")
t=data[:,0]
psi4_r=data[:,1]
psi4_i=data[:,2]
plt.plot(t-t[np.argmax(np.abs(psi4_r**2+psi4_i**2))],np.abs(psi4_r**2+psi4_i**2))

data=np.genfromtxt("NR_data_o10/strain_0_22_cutoff_low_0.005.dat")
t=data[:,0]
psi4_r=data[:,1]
psi4_i=data[:,2]
plt.plot(t-t[np.argmax(np.abs(psi4_r**2+psi4_i**2))],np.abs(psi4_r**2+psi4_i**2))

data=np.genfromtxt("NR_data_o20/strain_0_22_cutoff_low_0.005.dat")
t=data[:,0]
psi4_r=data[:,1]
psi4_i=data[:,2]
plt.plot(t-t[np.argmax(np.abs(psi4_r**2+psi4_i**2))],np.abs(psi4_r**2+psi4_i**2))

data=np.genfromtxt("NR_data_o30/strain_0_22_cutoff_low_0.005.dat")
t=data[:,0]
psi4_r=data[:,1]
psi4_i=data[:,2]
plt.plot(t-t[np.argmax(np.abs(psi4_r**2+psi4_i**2))],np.abs(psi4_r**2+psi4_i**2))

plt.legend(["0","o10","o20","o30"])
plt.xlim([-20,120])
# Out:
# (-20.0, 120.0)

# %%
data=np.genfromtxt("NR_data_0/strain_0_22_cutoff_low_0.005.dat")
t=data[:,0]
psi4_r=data[:,1]
psi4_i=data[:,2]
plt.plot(t,psi4_r)

data=np.genfromtxt("NR_data_o10/strain_0_22_cutoff_low_0.005.dat")
t=data[:,0]
psi4_r=data[:,1]
psi4_i=data[:,2]
plt.plot(t,psi4_r)

data=np.genfromtxt("NR_data_o20/strain_0_22_cutoff_low_0.005.dat")
t=data[:,0]
psi4_r=data[:,1]
psi4_i=data[:,2]
plt.plot(t,psi4_r)

data=np.genfromtxt("NR_data_o30/strain_0_22_cutoff_low_0.005.dat")
t=data[:,0]
psi4_r=data[:,1]
psi4_i=data[:,2]
plt.plot(t,psi4_r)

plt.legend(["0","o10","o20","o30"])
